# %% [markdown]
# # Examples for running FLORIS

# %%
# load modules
from floris.floris import Floris
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Setup floris and process input file

# %%
floris = Floris("Input_NREL5MW_SWF_5WT_8mps.json")

# %% [markdown]
# ## Calculate Wake

# %%
import time

t1 = time.time()

floris.farm.flow_field.calculate_wake()

t2 = time.time()

print('Time to compute wake = ', t2-t1, 's')
# Out:
# Time to compute wake =  0.03322005271911621 s

# %% [markdown]
# ## Compute Velocities at each Turbine

# %%
for coord, turbine in floris.farm.turbine_map.items():
    print(str(coord) + ":")
    print("\tCp -", turbine.Cp)
    print("\tCt -", turbine.Ct)
    print("\tpower -", turbine.power)
    print("\tai -", turbine.aI)
    print("\taverage velocity -", turbine.get_average_velocity())
# Out:
# (0.0, 0.0):
# 	Cp - [0.48390057]
# 	Ct - [0.76293975]
# 	power - [1685420.18637547]
# 	ai - [0.25655583]
# 	average velocity - 7.85065163365446
# (806.0, 0.0):
# 	Cp - [0.47908381]
# 	Ct - [0.73097301]
# 	power - [935361.30463895]
# 	ai - [0.24066094]
# 	average velocity - 6.47308024284217
# (1612.0, 0.0):
# 	Cp - [0.47624763]
# 	Ct - [0.72254242]
# 	power - [842216.02423978]
# 	ai - [0.23662879]
# 	average velocity - 6.263040872579965
# (2418.0, 0.0):
# 	Cp - [0.4751698]
# 	Ct - [0.71933856]
# 	power - [808589.0224308]
# 	ai - [0.23511255]
# 	average velocity - 6.183219890544633
# (3224.0, 0.0):
# 	Cp - [0.47467329]
# 	Ct - [0.71786268]
# 	power - [793419.30510157]
# 	ai - [0.234417]
# 	average velocity - 6.146449867299989

# %% [markdown]
# ## Visualization Manager for FLORIS

# %% [markdown]
# ## Optimize Wind Farm using Wake Steering

# %%
from floris.optimization import wake_steering
import numpy as np

# run FLORIS with no yaw
turbines    = [turbine for _, turbine in floris.farm.flow_field.turbine_map.items()]
for k,turbine in enumerate(turbines):
    turbine.yaw_angle = 0.0
floris.farm.flow_field.calculate_wake()
power_initial = np.sum([turbine.power for turbine in turbines])  # determine initial power production

# number of turbines
nTurbs = len(turbines)

# set bounds for the optimization on the yaw angles (deg)
minimum_yaw_angle = 0.0
maximum_yaw_angle = 25.0

# compute the optimal yaw angles
opt_yaw_angles = wake_steering(floris,minimum_yaw_angle,maximum_yaw_angle)

print('Optimal yaw angles for:')
for i,yaw in enumerate(opt_yaw_angles):
    print('Turbine ', i, ' yaw angle = ', np.degrees(yaw))
# Out:
# Optimal yaw angles for:
# Turbine  0  yaw angle =  24.999977366771244
# Turbine  1  yaw angle =  24.999999950886178
# Turbine  2  yaw angle =  24.01636526754824
# Turbine  3  yaw angle =  0.6324280137439906
# Turbine  4  yaw angle =  6.209636954692657e-08

# %% [markdown]
# ## Calculate Power Gain

# %%
# assign yaw angles to turbines
turbines    = [turbine for _, turbine in floris.farm.flow_field.turbine_map.items()]
for i,turbine in enumerate(turbines):
    turbine.yaw_angle = opt_yaw_angles[i]
    
# compute the new wake with yaw angles
floris.farm.flow_field.calculate_wake()

# optimal power 
power_opt = np.sum([turbine.power for turbine in turbines]) 

print('Power increased by ', 100*(power_opt-power_initial)/power_initial, '%')
# Out:
# Power increased by  10.372019662350423 %

# %% [markdown]
# ## Compute Annual Energy Production

# %%
# Visualization
from copy import deepcopy
from floris.visualization import VisualizationManager

ff_viz = deepcopy(floris.farm.flow_field)
grid_resolution = (100, 100, 50)
visualization_manager = VisualizationManager(ff_viz, grid_resolution)
visualization_manager.plot_z_planes([0.5])
visualization_manager.plot_x_planes([0.5])

# %%
from scipy.optimize import minimize
from floris.optimization import optimize_plant

t1 = time.time()

# wind speed and wind directions
wind_direction = np.linspace(0,350,36)
wind_speed = np.linspace(0,29,30)

# assume uniform distribution of wind speeds and wind directions 
# NOTE: user should specify specific distributions for their farms
freq = np.ones(len(wind_direction)*len(wind_speed))
freq = freq/np.sum(freq)

# initialize variables
power0    = np.zeros(len(wind_direction)*len(wind_speed))
powerOpt  = np.zeros(len(wind_direction)*len(wind_speed))
yawAngles = np.zeros((len(wind_direction)*len(wind_speed),nTurbs))
windSpeed = np.zeros(len(wind_direction)*len(wind_speed))
windDir   = np.zeros(len(wind_direction)*len(wind_speed))

count = 0

print('Optimizing AEP...')

for i,wd in enumerate(wind_direction):
    for j,ws in enumerate(wind_speed):
        
        print('Wind speed = ', ws, ' Wind direction = ', wd)
        
        # set initial wind direction and wind speed for FLORIS
        floris.farm.flow_field.wind_direction = np.radians(wd - 270) # frame of reference is west
        floris.farm.flow_field.wind_speed = ws
        floris.farm.flow_field.initial_flowfield = floris.farm.flow_field._initial_flowfield()
        floris.farm.flow_field.u_field = floris.farm.flow_field._initial_flowfield()
        
        # run FLORIS with no yaw
        turbines    = [turbine for _, turbine in floris.farm.flow_field.turbine_map.items()]
        for k,turbine in enumerate(turbines):
            turbine.yaw_angle = 0.0
            
        floris.farm.flow_field.calculate_wake()
        turbines    = [turbine for _, turbine in floris.farm.flow_field.turbine_map.items()]
        power0[count] = freq[count]*np.nan_to_num(np.sum([turbine.power for turbine in turbines]) )
        
        # optimize FLORIS for yaw
        # set initial conditions
        x0          = [np.radians(1.0) for turbine in turbines]
        bnds        = [(np.radians(minimum_yaw_angle), np.radians(maximum_yaw_angle)) for turbine in turbines]
        
        # optimize plant
        residual_plant = minimize(optimize_plant,x0,args=(floris),method='L-BFGS-B', bounds=bnds)
        turbines    = [turbine for _, turbine in floris.farm.flow_field.turbine_map.items()]
        for k,turbine in enumerate(turbines):
            turbine.yaw_angle = residual_plant.x[k]
            yawAngles[count,k] = residual_plant.x[k]
            
        floris.farm.flow_field.calculate_wake()
        turbines    = [turbine for _, turbine in floris.farm.flow_field.turbine_map.items()]
        powerOpt[count] = freq[count]*np.nan_to_num(np.sum([turbine.power for turbine in turbines]))
        
        #print('Power gain = ', 100*(powerOpt[count]-power0[count])/power0[count], power0[count],powerOpt[count])
        
        count = count + 1
        
print('AEP gain = ', 100*(np.sum(powerOpt)-np.sum(power0))/np.sum(power0))
t2 = time.time()

print('Total time for AEP optimization = ', t2-t1, 's')
# Out:
# Optimizing AEP...
# Wind speed =  0.0  Wind direction =  0.0
# Wind speed =  1.0  Wind direction =  0.0
# Wind speed =  2.0  Wind direction =  0.0
# Wind speed =  3.0  Wind direction =  0.0
# Wind speed =  4.0  Wind direction =  0.0
# Wind speed =  5.0  Wind direction =  0.0
# Wind speed =  6.0  Wind direction =  0.0
# Wind speed =  7.0  Wind direction =  0.0
# Wind speed =  8.0  Wind direction =  0.0
# Wind speed =  9.0  Wind direction =  0.0
# Wind speed =  10.0  Wind direction =  0.0
# Wind speed =  11.0  Wind direction =  0.0
# Wind speed =  12.0  Wind direction =  0.0
# Wind speed =  13.0  Wind direction =  0.0
# Wind speed =  14.0  Wind direction =  0.0
# Wind speed =  15.0  Wind direction =  0.0
# Wind speed =  16.0  Wind direction =  0.0
# Wind speed =  17.0  Wind direction =  0.0
# Wind speed =  18.0  Wind direction =  0.0
# Wind speed =  19.0  Wind direction =  0.0
# Wind speed =  20.0  Wind direction =  0.0
# Wind speed =  21.0  Wind direction =  0.0
# Wind speed =  22.0  Wind direction =  0.0
# Wind speed =  23.0  Wind direction =  0.0
# Wind speed =  24.0  Wind direction =  0.0
# Wind speed =  25.0  Wind direction =  0.0
# Wind speed =  26.0  Wind direction =  0.0
# Wind speed =  27.0  Wind direction =  0.0
# Wind speed =  28.0  Wind direction =  0.0
# Wind speed =  29.0  Wind direction =  0.0
# Wind speed =  0.0  Wind direction =  10.0
# Wind speed =  1.0  Wind direction =  10.0
# Wind speed =  2.0  Wind direction =  10.0
# Wind speed =  3.0  Wind direction =  10.0
# Wind speed =  4.0  Wind direction =  10.0
# Wind speed =  5.0  Wind direction =  10.0
# Wind speed =  6.0  Wind direction =  10.0
# Wind speed =  7.0  Wind direction =  10.0
# Wind speed =  8.0  Wind direction =  10.0
# Wind speed =  9.0  Wind direction =  10.0
# Wind speed =  10.0  Wind direction =  10.0
# Wind speed =  11.0  Wind direction =  10.0
# Wind speed =  12.0  Wind direction =  10.0
# Wind speed =  13.0  Wind direction =  10.0
# Wind speed =  14.0  Wind direction =  10.0
# Wind speed =  15.0  Wind direction =  10.0
# Wind speed =  16.0  Wind direction =  10.0
# Wind speed =  17.0  Wind direction =  10.0
# Wind speed =  18.0  Wind direction =  10.0
# Wind speed =  19.0  Wind direction =  10.0
# Wind speed =  20.0  Wind direction =  10.0
# Wind speed =  21.0  Wind direction =  10.0
# Wind speed =  22.0  Wind direction =  10.0
# Wind speed =  23.0  Wind direction =  10.0
# Wind speed =  24.0  Wind direction =  10.0
# Wind speed =  25.0  Wind direction =  10.0
# Wind speed =  26.0  Wind direction =  10.0
# Wind speed =  27.0  Wind direction =  10.0
# Wind speed =  28.0  Wind direction =  10.0
# Wind speed =  29.0  Wind direction =  10.0
# Wind speed =  0.0  Wind direction =  20.0
# Wind speed =  1.0  Wind direction =  20.0
# Wind speed =  2.0  Wind direction =  20.0
# Wind speed =  3.0  Wind direction =  20.0
# Wind speed =  4.0  Wind direction =  20.0
# Wind speed =  5.0  Wind direction =  20.0
# Wind speed =  6.0  Wind direction =  20.0
# Wind speed =  7.0  Wind direction =  20.0
# Wind speed =  8.0  Wind direction =  20.0
# Wind speed =  9.0  Wind direction =  20.0
# Wind speed =  10.0  Wind direction =  20.0
# Wind speed =  11.0  Wind direction =  20.0
# Wind speed =  12.0  Wind direction =  20.0
# Wind speed =  13.0  Wind direction =  20.0
# Wind speed =  14.0  Wind direction =  20.0
# Wind speed =  15.0  Wind direction =  20.0
# Wind speed =  16.0  Wind direction =  20.0
# Wind speed =  17.0  Wind direction =  20.0
# Wind speed =  18.0  Wind direction =  20.0
# Wind speed =  19.0  Wind direction =  20.0
# Wind speed =  20.0  Wind direction =  20.0
# Wind speed =  21.0  Wind direction =  20.0
# Wind speed =  22.0  Wind direction =  20.0
# Wind speed =  23.0  Wind direction =  20.0
# Wind speed =  24.0  Wind direction =  20.0
# Wind speed =  25.0  Wind direction =  20.0
# Wind speed =  26.0  Wind direction =  20.0
# Wind speed =  27.0  Wind direction =  20.0
# Wind speed =  28.0  Wind direction =  20.0
# Wind speed =  29.0  Wind direction =  20.0
# Wind speed =  0.0  Wind direction =  30.0
# Wind speed =  1.0  Wind direction =  30.0
# Wind speed =  2.0  Wind direction =  30.0
# Wind speed =  3.0  Wind direction =  30.0
# Wind speed =  4.0  Wind direction =  30.0
# Wind speed =  5.0  Wind direction =  30.0
# Wind speed =  6.0  Wind direction =  30.0
# Wind speed =  7.0  Wind direction =  30.0
# Wind speed =  8.0  Wind direction =  30.0
# Wind speed =  9.0  Wind direction =  30.0
# Wind speed =  10.0  Wind direction =  30.0
# Wind speed =  11.0  Wind direction =  30.0
# Wind speed =  12.0  Wind direction =  30.0
# Wind speed =  13.0  Wind direction =  30.0
# Wind speed =  14.0  Wind direction =  30.0
# Wind speed =  15.0  Wind direction =  30.0
# Wind speed =  16.0  Wind direction =  30.0
# Wind speed =  17.0  Wind direction =  30.0
# Wind speed =  18.0  Wind direction =  30.0
# Wind speed =  19.0  Wind direction =  30.0
# Wind speed =  20.0  Wind direction =  30.0
# Wind speed =  21.0  Wind direction =  30.0
# Wind speed =  22.0  Wind direction =  30.0
# Wind speed =  23.0  Wind direction =  30.0
# Wind speed =  24.0  Wind direction =  30.0
# Wind speed =  25.0  Wind direction =  30.0
# Wind speed =  26.0  Wind direction =  30.0
# Wind speed =  27.0  Wind direction =  30.0
# Wind speed =  28.0  Wind direction =  30.0
# Wind speed =  29.0  Wind direction =  30.0
# Wind speed =  0.0  Wind direction =  40.0
# Wind speed =  1.0  Wind direction =  40.0
# Wind speed =  2.0  Wind direction =  40.0
# Wind speed =  3.0  Wind direction =  40.0
# Wind speed =  4.0  Wind direction =  40.0
# Wind speed =  5.0  Wind direction =  40.0
# Wind speed =  6.0  Wind direction =  40.0
# Wind speed =  7.0  Wind direction =  40.0
# Wind speed =  8.0  Wind direction =  40.0
# Wind speed =  9.0  Wind direction =  40.0
# Wind speed =  10.0  Wind direction =  40.0
# Wind speed =  11.0  Wind direction =  40.0
# Wind speed =  12.0  Wind direction =  40.0
# Wind speed =  13.0  Wind direction =  40.0
# Wind speed =  14.0  Wind direction =  40.0
# Wind speed =  15.0  Wind direction =  40.0
# Wind speed =  16.0  Wind direction =  40.0
# Wind speed =  17.0  Wind direction =  40.0
# Wind speed =  18.0  Wind direction =  40.0
# Wind speed =  19.0  Wind direction =  40.0
# Wind speed =  20.0  Wind direction =  40.0
# Wind speed =  21.0  Wind direction =  40.0
# Wind speed =  22.0  Wind direction =  40.0
# Wind speed =  23.0  Wind direction =  40.0
# Wind speed =  24.0  Wind direction =  40.0
# Wind speed =  25.0  Wind direction =  40.0
# Wind speed =  26.0  Wind direction =  40.0
# Wind speed =  27.0  Wind direction =  40.0
# Wind speed =  28.0  Wind direction =  40.0
# Wind speed =  29.0  Wind direction =  40.0
# Wind speed =  0.0  Wind direction =  50.0
# Wind speed =  1.0  Wind direction =  50.0
# Wind speed =  2.0  Wind direction =  50.0
# Wind speed =  3.0  Wind direction =  50.0
# Wind speed =  4.0  Wind direction =  50.0
# Wind speed =  5.0  Wind direction =  50.0
# Wind speed =  6.0  Wind direction =  50.0
# Wind speed =  7.0  Wind direction =  50.0
# Wind speed =  8.0  Wind direction =  50.0
# Wind speed =  9.0  Wind direction =  50.0
# Wind speed =  10.0  Wind direction =  50.0
# Wind speed =  11.0  Wind direction =  50.0
# Wind speed =  12.0  Wind direction =  50.0
# Wind speed =  13.0  Wind direction =  50.0
# Wind speed =  14.0  Wind direction =  50.0
# Wind speed =  15.0  Wind direction =  50.0
# Wind speed =  16.0  Wind direction =  50.0
# Wind speed =  17.0  Wind direction =  50.0
# Wind speed =  18.0  Wind direction =  50.0
# Wind speed =  19.0  Wind direction =  50.0
# Wind speed =  20.0  Wind direction =  50.0
# Wind speed =  21.0  Wind direction =  50.0
# Wind speed =  22.0  Wind direction =  50.0
# Wind speed =  23.0  Wind direction =  50.0
# Wind speed =  24.0  Wind direction =  50.0
# Wind speed =  25.0  Wind direction =  50.0
# Wind speed =  26.0  Wind direction =  50.0
# Wind speed =  27.0  Wind direction =  50.0
# Wind speed =  28.0  Wind direction =  50.0
# Wind speed =  29.0  Wind direction =  50.0
# Wind speed =  0.0  Wind direction =  60.0
# Wind speed =  1.0  Wind direction =  60.0
# Wind speed =  2.0  Wind direction =  60.0
# Wind speed =  3.0  Wind direction =  60.0
# Wind speed =  4.0  Wind direction =  60.0
# Wind speed =  5.0  Wind direction =  60.0
# Wind speed =  6.0  Wind direction =  60.0
# Wind speed =  7.0  Wind direction =  60.0
# Wind speed =  8.0  Wind direction =  60.0
# Wind speed =  9.0  Wind direction =  60.0
# Wind speed =  10.0  Wind direction =  60.0
# Wind speed =  11.0  Wind direction =  60.0
# Wind speed =  12.0  Wind direction =  60.0
# Wind speed =  13.0  Wind direction =  60.0
# Wind speed =  14.0  Wind direction =  60.0
# Wind speed =  15.0  Wind direction =  60.0
# Wind speed =  16.0  Wind direction =  60.0
# Wind speed =  17.0  Wind direction =  60.0
# Wind speed =  18.0  Wind direction =  60.0
# Wind speed =  19.0  Wind direction =  60.0
# Wind speed =  20.0  Wind direction =  60.0
# Wind speed =  21.0  Wind direction =  60.0
# Wind speed =  22.0  Wind direction =  60.0
# Wind speed =  23.0  Wind direction =  60.0
# Wind speed =  24.0  Wind direction =  60.0
# Wind speed =  25.0  Wind direction =  60.0
# Wind speed =  26.0  Wind direction =  60.0
# Wind speed =  27.0  Wind direction =  60.0
# Wind speed =  28.0  Wind direction =  60.0
# Wind speed =  29.0  Wind direction =  60.0
# Wind speed =  0.0  Wind direction =  70.0
# Wind speed =  1.0  Wind direction =  70.0
# Wind speed =  2.0  Wind direction =  70.0
# Wind speed =  3.0  Wind direction =  70.0
# Wind speed =  4.0  Wind direction =  70.0
# Wind speed =  5.0  Wind direction =  70.0
# Wind speed =  6.0  Wind direction =  70.0
# Wind speed =  7.0  Wind direction =  70.0
# Wind speed =  8.0  Wind direction =  70.0
# Wind speed =  9.0  Wind direction =  70.0
# Wind speed =  10.0  Wind direction =  70.0
# Wind speed =  11.0  Wind direction =  70.0
# Wind speed =  12.0  Wind direction =  70.0
# Wind speed =  13.0  Wind direction =  70.0
# Wind speed =  14.0  Wind direction =  70.0
# Wind speed =  15.0  Wind direction =  70.0
# Wind speed =  16.0  Wind direction =  70.0
# Wind speed =  17.0  Wind direction =  70.0
# Wind speed =  18.0  Wind direction =  70.0
# Wind speed =  19.0  Wind direction =  70.0
# Wind speed =  20.0  Wind direction =  70.0
# Wind speed =  21.0  Wind direction =  70.0
# Wind speed =  22.0  Wind direction =  70.0
# Wind speed =  23.0  Wind direction =  70.0
# Wind speed =  24.0  Wind direction =  70.0
# Wind speed =  25.0  Wind direction =  70.0
# Wind speed =  26.0  Wind direction =  70.0
# Wind speed =  27.0  Wind direction =  70.0
# Wind speed =  28.0  Wind direction =  70.0
# Wind speed =  29.0  Wind direction =  70.0
# Wind speed =  0.0  Wind direction =  80.0
# Wind speed =  1.0  Wind direction =  80.0
# Wind speed =  2.0  Wind direction =  80.0
# Wind speed =  3.0  Wind direction =  80.0
# Wind speed =  4.0  Wind direction =  80.0
# Wind speed =  5.0  Wind direction =  80.0
# Wind speed =  6.0  Wind direction =  80.0
# Wind speed =  7.0  Wind direction =  80.0
# Wind speed =  8.0  Wind direction =  80.0
# Wind speed =  9.0  Wind direction =  80.0
# Wind speed =  10.0  Wind direction =  80.0
# Wind speed =  11.0  Wind direction =  80.0
# Wind speed =  12.0  Wind direction =  80.0
# Wind speed =  13.0  Wind direction =  80.0
# Wind speed =  14.0  Wind direction =  80.0
# Wind speed =  15.0  Wind direction =  80.0
# Wind speed =  16.0  Wind direction =  80.0
# Wind speed =  17.0  Wind direction =  80.0
# Wind speed =  18.0  Wind direction =  80.0
# Wind speed =  19.0  Wind direction =  80.0
# Wind speed =  20.0  Wind direction =  80.0
# Wind speed =  21.0  Wind direction =  80.0
# Wind speed =  22.0  Wind direction =  80.0
# Wind speed =  23.0  Wind direction =  80.0
# Wind speed =  24.0  Wind direction =  80.0
# Wind speed =  25.0  Wind direction =  80.0
# Wind speed =  26.0  Wind direction =  80.0
# Wind speed =  27.0  Wind direction =  80.0
# Wind speed =  28.0  Wind direction =  80.0
# Wind speed =  29.0  Wind direction =  80.0
# Wind speed =  0.0  Wind direction =  90.0
# Wind speed =  1.0  Wind direction =  90.0
# Wind speed =  2.0  Wind direction =  90.0
# Wind speed =  3.0  Wind direction =  90.0
# Wind speed =  4.0  Wind direction =  90.0
# Wind speed =  5.0  Wind direction =  90.0
# Wind speed =  6.0  Wind direction =  90.0
# Wind speed =  7.0  Wind direction =  90.0
# Wind speed =  8.0  Wind direction =  90.0
# Wind speed =  9.0  Wind direction =  90.0
# Wind speed =  10.0  Wind direction =  90.0
# Wind speed =  11.0  Wind direction =  90.0
# Wind speed =  12.0  Wind direction =  90.0
# Wind speed =  13.0  Wind direction =  90.0
# Wind speed =  14.0  Wind direction =  90.0
# Wind speed =  15.0  Wind direction =  90.0
# Wind speed =  16.0  Wind direction =  90.0
# Wind speed =  17.0  Wind direction =  90.0
# Wind speed =  18.0  Wind direction =  90.0
# Wind speed =  19.0  Wind direction =  90.0
# Wind speed =  20.0  Wind direction =  90.0
# Wind speed =  21.0  Wind direction =  90.0
# Wind speed =  22.0  Wind direction =  90.0
# Wind speed =  23.0  Wind direction =  90.0
# Wind speed =  24.0  Wind direction =  90.0
# Wind speed =  25.0  Wind direction =  90.0
# Wind speed =  26.0  Wind direction =  90.0
# Wind speed =  27.0  Wind direction =  90.0
# Wind speed =  28.0  Wind direction =  90.0
# Wind speed =  29.0  Wind direction =  90.0
# Wind speed =  0.0  Wind direction =  100.0
# Wind speed =  1.0  Wind direction =  100.0
# Wind speed =  2.0  Wind direction =  100.0
# Wind speed =  3.0  Wind direction =  100.0
# Wind speed =  4.0  Wind direction =  100.0
# Wind speed =  5.0  Wind direction =  100.0
# Wind speed =  6.0  Wind direction =  100.0
# Wind speed =  7.0  Wind direction =  100.0
# Wind speed =  8.0  Wind direction =  100.0
# Wind speed =  9.0  Wind direction =  100.0
# Wind speed =  10.0  Wind direction =  100.0
# Wind speed =  11.0  Wind direction =  100.0
# Wind speed =  12.0  Wind direction =  100.0
# Wind speed =  13.0  Wind direction =  100.0
# Wind speed =  14.0  Wind direction =  100.0
# Wind speed =  15.0  Wind direction =  100.0
# Wind speed =  16.0  Wind direction =  100.0
# Wind speed =  17.0  Wind direction =  100.0
# Wind speed =  18.0  Wind direction =  100.0
# Wind speed =  19.0  Wind direction =  100.0
# Wind speed =  20.0  Wind direction =  100.0
# Wind speed =  21.0  Wind direction =  100.0
# Wind speed =  22.0  Wind direction =  100.0
# Wind speed =  23.0  Wind direction =  100.0
# Wind speed =  24.0  Wind direction =  100.0
# Wind speed =  25.0  Wind direction =  100.0
# Wind speed =  26.0  Wind direction =  100.0
# Wind speed =  27.0  Wind direction =  100.0
# Wind speed =  28.0  Wind direction =  100.0
# Wind speed =  29.0  Wind direction =  100.0
# Wind speed =  0.0  Wind direction =  110.0
# Wind speed =  1.0  Wind direction =  110.0
# Wind speed =  2.0  Wind direction =  110.0
# Wind speed =  3.0  Wind direction =  110.0
# Wind speed =  4.0  Wind direction =  110.0
# Wind speed =  5.0  Wind direction =  110.0
# Wind speed =  6.0  Wind direction =  110.0
# Wind speed =  7.0  Wind direction =  110.0
# Wind speed =  8.0  Wind direction =  110.0
# Wind speed =  9.0  Wind direction =  110.0
# Wind speed =  10.0  Wind direction =  110.0
# Wind speed =  11.0  Wind direction =  110.0
# Wind speed =  12.0  Wind direction =  110.0
# Wind speed =  13.0  Wind direction =  110.0
# Wind speed =  14.0  Wind direction =  110.0
# Wind speed =  15.0  Wind direction =  110.0
# Wind speed =  16.0  Wind direction =  110.0
# Wind speed =  17.0  Wind direction =  110.0
# Wind speed =  18.0  Wind direction =  110.0
# Wind speed =  19.0  Wind direction =  110.0
# Wind speed =  20.0  Wind direction =  110.0
# Wind speed =  21.0  Wind direction =  110.0
# Wind speed =  22.0  Wind direction =  110.0
# Wind speed =  23.0  Wind direction =  110.0
# Wind speed =  24.0  Wind direction =  110.0
# Wind speed =  25.0  Wind direction =  110.0
# Wind speed =  26.0  Wind direction =  110.0
# Wind speed =  27.0  Wind direction =  110.0
# Wind speed =  28.0  Wind direction =  110.0
# Wind speed =  29.0  Wind direction =  110.0
# Wind speed =  0.0  Wind direction =  120.0
# Wind speed =  1.0  Wind direction =  120.0
# Wind speed =  2.0  Wind direction =  120.0
# Wind speed =  3.0  Wind direction =  120.0
# Wind speed =  4.0  Wind direction =  120.0
# Wind speed =  5.0  Wind direction =  120.0
# Wind speed =  6.0  Wind direction =  120.0
# Wind speed =  7.0  Wind direction =  120.0
# Wind speed =  8.0  Wind direction =  120.0
# Wind speed =  9.0  Wind direction =  120.0
# Wind speed =  10.0  Wind direction =  120.0
# Wind speed =  11.0  Wind direction =  120.0
# Wind speed =  12.0  Wind direction =  120.0
# Wind speed =  13.0  Wind direction =  120.0
# Wind speed =  14.0  Wind direction =  120.0
# Wind speed =  15.0  Wind direction =  120.0
# Wind speed =  16.0  Wind direction =  120.0
# Wind speed =  17.0  Wind direction =  120.0
# Wind speed =  18.0  Wind direction =  120.0
# Wind speed =  19.0  Wind direction =  120.0
# Wind speed =  20.0  Wind direction =  120.0
# Wind speed =  21.0  Wind direction =  120.0
# Wind speed =  22.0  Wind direction =  120.0
# Wind speed =  23.0  Wind direction =  120.0
# Wind speed =  24.0  Wind direction =  120.0
# Wind speed =  25.0  Wind direction =  120.0
# Wind speed =  26.0  Wind direction =  120.0
# Wind speed =  27.0  Wind direction =  120.0
# Wind speed =  28.0  Wind direction =  120.0
# Wind speed =  29.0  Wind direction =  120.0
# Wind speed =  0.0  Wind direction =  130.0
# Wind speed =  1.0  Wind direction =  130.0
# Wind speed =  2.0  Wind direction =  130.0
# Wind speed =  3.0  Wind direction =  130.0
# Wind speed =  4.0  Wind direction =  130.0
# Wind speed =  5.0  Wind direction =  130.0
# Wind speed =  6.0  Wind direction =  130.0
# Wind speed =  7.0  Wind direction =  130.0
# Wind speed =  8.0  Wind direction =  130.0
# Wind speed =  9.0  Wind direction =  130.0
# Wind speed =  10.0  Wind direction =  130.0
# Wind speed =  11.0  Wind direction =  130.0
# Wind speed =  12.0  Wind direction =  130.0
# Wind speed =  13.0  Wind direction =  130.0
# Wind speed =  14.0  Wind direction =  130.0
# Wind speed =  15.0  Wind direction =  130.0
# Wind speed =  16.0  Wind direction =  130.0
# Wind speed =  17.0  Wind direction =  130.0
# Wind speed =  18.0  Wind direction =  130.0
# Wind speed =  19.0  Wind direction =  130.0
# Wind speed =  20.0  Wind direction =  130.0
# Wind speed =  21.0  Wind direction =  130.0
# Wind speed =  22.0  Wind direction =  130.0
# Wind speed =  23.0  Wind direction =  130.0
# Wind speed =  24.0  Wind direction =  130.0
# Wind speed =  25.0  Wind direction =  130.0
# Wind speed =  26.0  Wind direction =  130.0
# Wind speed =  27.0  Wind direction =  130.0
# Wind speed =  28.0  Wind direction =  130.0
# Wind speed =  29.0  Wind direction =  130.0
# Wind speed =  0.0  Wind direction =  140.0
# Wind speed =  1.0  Wind direction =  140.0
# Wind speed =  2.0  Wind direction =  140.0
# Wind speed =  3.0  Wind direction =  140.0
# Wind speed =  4.0  Wind direction =  140.0
# Wind speed =  5.0  Wind direction =  140.0
# Wind speed =  6.0  Wind direction =  140.0
# Wind speed =  7.0  Wind direction =  140.0
# Wind speed =  8.0  Wind direction =  140.0
# Wind speed =  9.0  Wind direction =  140.0
# Wind speed =  10.0  Wind direction =  140.0
# Wind speed =  11.0  Wind direction =  140.0
# Wind speed =  12.0  Wind direction =  140.0
# Wind speed =  13.0  Wind direction =  140.0
# Wind speed =  14.0  Wind direction =  140.0
# Wind speed =  15.0  Wind direction =  140.0
# Wind speed =  16.0  Wind direction =  140.0
# Wind speed =  17.0  Wind direction =  140.0
# Wind speed =  18.0  Wind direction =  140.0
# Wind speed =  19.0  Wind direction =  140.0
# Wind speed =  20.0  Wind direction =  140.0
# Wind speed =  21.0  Wind direction =  140.0
# Wind speed =  22.0  Wind direction =  140.0
# Wind speed =  23.0  Wind direction =  140.0
# Wind speed =  24.0  Wind direction =  140.0
# Wind speed =  25.0  Wind direction =  140.0
# Wind speed =  26.0  Wind direction =  140.0
# Wind speed =  27.0  Wind direction =  140.0
# Wind speed =  28.0  Wind direction =  140.0
# Wind speed =  29.0  Wind direction =  140.0
# Wind speed =  0.0  Wind direction =  150.0
# Wind speed =  1.0  Wind direction =  150.0
# Wind speed =  2.0  Wind direction =  150.0
# Wind speed =  3.0  Wind direction =  150.0
# Wind speed =  4.0  Wind direction =  150.0
# Wind speed =  5.0  Wind direction =  150.0
# Wind speed =  6.0  Wind direction =  150.0
# Wind speed =  7.0  Wind direction =  150.0
# Wind speed =  8.0  Wind direction =  150.0
# Wind speed =  9.0  Wind direction =  150.0
# Wind speed =  10.0  Wind direction =  150.0
# Wind speed =  11.0  Wind direction =  150.0
# Wind speed =  12.0  Wind direction =  150.0
# Wind speed =  13.0  Wind direction =  150.0
# Wind speed =  14.0  Wind direction =  150.0
# Wind speed =  15.0  Wind direction =  150.0
# Wind speed =  16.0  Wind direction =  150.0
# Wind speed =  17.0  Wind direction =  150.0
# Wind speed =  18.0  Wind direction =  150.0
# Wind speed =  19.0  Wind direction =  150.0
# Wind speed =  20.0  Wind direction =  150.0
# Wind speed =  21.0  Wind direction =  150.0
# Wind speed =  22.0  Wind direction =  150.0
# Wind speed =  23.0  Wind direction =  150.0
# Wind speed =  24.0  Wind direction =  150.0
# Wind speed =  25.0  Wind direction =  150.0
# Wind speed =  26.0  Wind direction =  150.0
# Wind speed =  27.0  Wind direction =  150.0
# Wind speed =  28.0  Wind direction =  150.0
# Wind speed =  29.0  Wind direction =  150.0
# Wind speed =  0.0  Wind direction =  160.0
# Wind speed =  1.0  Wind direction =  160.0
# Wind speed =  2.0  Wind direction =  160.0
# Wind speed =  3.0  Wind direction =  160.0
# Wind speed =  4.0  Wind direction =  160.0
# Wind speed =  5.0  Wind direction =  160.0
# Wind speed =  6.0  Wind direction =  160.0
# Wind speed =  7.0  Wind direction =  160.0
# Wind speed =  8.0  Wind direction =  160.0
# Wind speed =  9.0  Wind direction =  160.0
# Wind speed =  10.0  Wind direction =  160.0
# Wind speed =  11.0  Wind direction =  160.0
# Wind speed =  12.0  Wind direction =  160.0
# Wind speed =  13.0  Wind direction =  160.0
# Wind speed =  14.0  Wind direction =  160.0
# Wind speed =  15.0  Wind direction =  160.0
# Wind speed =  16.0  Wind direction =  160.0
# Wind speed =  17.0  Wind direction =  160.0
# Wind speed =  18.0  Wind direction =  160.0
# Wind speed =  19.0  Wind direction =  160.0
# Wind speed =  20.0  Wind direction =  160.0
# Wind speed =  21.0  Wind direction =  160.0
# Wind speed =  22.0  Wind direction =  160.0
# Wind speed =  23.0  Wind direction =  160.0
# Wind speed =  24.0  Wind direction =  160.0
# Wind speed =  25.0  Wind direction =  160.0
# Wind speed =  26.0  Wind direction =  160.0
# Wind speed =  27.0  Wind direction =  160.0
# Wind speed =  28.0  Wind direction =  160.0
# Wind speed =  29.0  Wind direction =  160.0
# Wind speed =  0.0  Wind direction =  170.0
# Wind speed =  1.0  Wind direction =  170.0
# Wind speed =  2.0  Wind direction =  170.0
# Wind speed =  3.0  Wind direction =  170.0
# Wind speed =  4.0  Wind direction =  170.0
# Wind speed =  5.0  Wind direction =  170.0
# Wind speed =  6.0  Wind direction =  170.0
# Wind speed =  7.0  Wind direction =  170.0
# Wind speed =  8.0  Wind direction =  170.0
# Wind speed =  9.0  Wind direction =  170.0
# Wind speed =  10.0  Wind direction =  170.0
# Wind speed =  11.0  Wind direction =  170.0
# Wind speed =  12.0  Wind direction =  170.0
# Wind speed =  13.0  Wind direction =  170.0
# Wind speed =  14.0  Wind direction =  170.0
# Wind speed =  15.0  Wind direction =  170.0
# Wind speed =  16.0  Wind direction =  170.0
# Wind speed =  17.0  Wind direction =  170.0
# Wind speed =  18.0  Wind direction =  170.0
# Wind speed =  19.0  Wind direction =  170.0
# Wind speed =  20.0  Wind direction =  170.0
# Wind speed =  21.0  Wind direction =  170.0
# Wind speed =  22.0  Wind direction =  170.0
# Wind speed =  23.0  Wind direction =  170.0
# Wind speed =  24.0  Wind direction =  170.0
# Wind speed =  25.0  Wind direction =  170.0
# Wind speed =  26.0  Wind direction =  170.0
# Wind speed =  27.0  Wind direction =  170.0
# Wind speed =  28.0  Wind direction =  170.0
# Wind speed =  29.0  Wind direction =  170.0
# Wind speed =  0.0  Wind direction =  180.0
# Wind speed =  1.0  Wind direction =  180.0
# Wind speed =  2.0  Wind direction =  180.0
# Wind speed =  3.0  Wind direction =  180.0
# Wind speed =  4.0  Wind direction =  180.0
# Wind speed =  5.0  Wind direction =  180.0
# Wind speed =  6.0  Wind direction =  180.0
# Wind speed =  7.0  Wind direction =  180.0
# Wind speed =  8.0  Wind direction =  180.0
# Wind speed =  9.0  Wind direction =  180.0
# Wind speed =  10.0  Wind direction =  180.0
# Wind speed =  11.0  Wind direction =  180.0
# Wind speed =  12.0  Wind direction =  180.0
# Wind speed =  13.0  Wind direction =  180.0
# Wind speed =  14.0  Wind direction =  180.0
# Wind speed =  15.0  Wind direction =  180.0
# Wind speed =  16.0  Wind direction =  180.0
# Wind speed =  17.0  Wind direction =  180.0
# Wind speed =  18.0  Wind direction =  180.0
# Wind speed =  19.0  Wind direction =  180.0
# Wind speed =  20.0  Wind direction =  180.0
# Wind speed =  21.0  Wind direction =  180.0
# Wind speed =  22.0  Wind direction =  180.0
# Wind speed =  23.0  Wind direction =  180.0
# Wind speed =  24.0  Wind direction =  180.0
# Wind speed =  25.0  Wind direction =  180.0
# Wind speed =  26.0  Wind direction =  180.0
# Wind speed =  27.0  Wind direction =  180.0
# Wind speed =  28.0  Wind direction =  180.0
# Wind speed =  29.0  Wind direction =  180.0
# Wind speed =  0.0  Wind direction =  190.0
# Wind speed =  1.0  Wind direction =  190.0
# Wind speed =  2.0  Wind direction =  190.0
# Wind speed =  3.0  Wind direction =  190.0
# Wind speed =  4.0  Wind direction =  190.0
# Wind speed =  5.0  Wind direction =  190.0
# Wind speed =  6.0  Wind direction =  190.0
# Wind speed =  7.0  Wind direction =  190.0
# Wind speed =  8.0  Wind direction =  190.0
# Wind speed =  9.0  Wind direction =  190.0
# Wind speed =  10.0  Wind direction =  190.0
# Wind speed =  11.0  Wind direction =  190.0
# Wind speed =  12.0  Wind direction =  190.0
# Wind speed =  13.0  Wind direction =  190.0
# Wind speed =  14.0  Wind direction =  190.0
# Wind speed =  15.0  Wind direction =  190.0
# Wind speed =  16.0  Wind direction =  190.0
# Wind speed =  17.0  Wind direction =  190.0
# Wind speed =  18.0  Wind direction =  190.0
# Wind speed =  19.0  Wind direction =  190.0
# Wind speed =  20.0  Wind direction =  190.0
# Wind speed =  21.0  Wind direction =  190.0
# Wind speed =  22.0  Wind direction =  190.0
# Wind speed =  23.0  Wind direction =  190.0
# Wind speed =  24.0  Wind direction =  190.0
# Wind speed =  25.0  Wind direction =  190.0
# Wind speed =  26.0  Wind direction =  190.0
# Wind speed =  27.0  Wind direction =  190.0
# Wind speed =  28.0  Wind direction =  190.0
# Wind speed =  29.0  Wind direction =  190.0
# Wind speed =  0.0  Wind direction =  200.0
# Wind speed =  1.0  Wind direction =  200.0
# Wind speed =  2.0  Wind direction =  200.0
# Wind speed =  3.0  Wind direction =  200.0
# Wind speed =  4.0  Wind direction =  200.0
# Wind speed =  5.0  Wind direction =  200.0
# Wind speed =  6.0  Wind direction =  200.0
# Wind speed =  7.0  Wind direction =  200.0
# Wind speed =  8.0  Wind direction =  200.0
# Wind speed =  9.0  Wind direction =  200.0
# Wind speed =  10.0  Wind direction =  200.0
# Wind speed =  11.0  Wind direction =  200.0
# Wind speed =  12.0  Wind direction =  200.0
# Wind speed =  13.0  Wind direction =  200.0
# Wind speed =  14.0  Wind direction =  200.0
# Wind speed =  15.0  Wind direction =  200.0
# Wind speed =  16.0  Wind direction =  200.0
# Wind speed =  17.0  Wind direction =  200.0
# Wind speed =  18.0  Wind direction =  200.0
# Wind speed =  19.0  Wind direction =  200.0
# Wind speed =  20.0  Wind direction =  200.0
# Wind speed =  21.0  Wind direction =  200.0
# Wind speed =  22.0  Wind direction =  200.0
# Wind speed =  23.0  Wind direction =  200.0
# Wind speed =  24.0  Wind direction =  200.0
# Wind speed =  25.0  Wind direction =  200.0
# Wind speed =  26.0  Wind direction =  200.0
# Wind speed =  27.0  Wind direction =  200.0
# Wind speed =  28.0  Wind direction =  200.0
# Wind speed =  29.0  Wind direction =  200.0
# Wind speed =  0.0  Wind direction =  210.0
# Wind speed =  1.0  Wind direction =  210.0
# Wind speed =  2.0  Wind direction =  210.0
# Wind speed =  3.0  Wind direction =  210.0
# Wind speed =  4.0  Wind direction =  210.0
# Wind speed =  5.0  Wind direction =  210.0
# Wind speed =  6.0  Wind direction =  210.0
# Wind speed =  7.0  Wind direction =  210.0
# Wind speed =  8.0  Wind direction =  210.0
# Wind speed =  9.0  Wind direction =  210.0
# Wind speed =  10.0  Wind direction =  210.0
# Wind speed =  11.0  Wind direction =  210.0
# Wind speed =  12.0  Wind direction =  210.0
# Wind speed =  13.0  Wind direction =  210.0
# Wind speed =  14.0  Wind direction =  210.0
# Wind speed =  15.0  Wind direction =  210.0
# Wind speed =  16.0  Wind direction =  210.0
# Wind speed =  17.0  Wind direction =  210.0
# Wind speed =  18.0  Wind direction =  210.0
# Wind speed =  19.0  Wind direction =  210.0
# Wind speed =  20.0  Wind direction =  210.0
# Wind speed =  21.0  Wind direction =  210.0
# Wind speed =  22.0  Wind direction =  210.0
# Wind speed =  23.0  Wind direction =  210.0
# Wind speed =  24.0  Wind direction =  210.0
# Wind speed =  25.0  Wind direction =  210.0
# Wind speed =  26.0  Wind direction =  210.0
# Wind speed =  27.0  Wind direction =  210.0
# Wind speed =  28.0  Wind direction =  210.0
# Wind speed =  29.0  Wind direction =  210.0
# Wind speed =  0.0  Wind direction =  220.0
# Wind speed =  1.0  Wind direction =  220.0
# Wind speed =  2.0  Wind direction =  220.0
# Wind speed =  3.0  Wind direction =  220.0
# Wind speed =  4.0  Wind direction =  220.0
# Wind speed =  5.0  Wind direction =  220.0
# Wind speed =  6.0  Wind direction =  220.0
# Wind speed =  7.0  Wind direction =  220.0
# Wind speed =  8.0  Wind direction =  220.0
# Wind speed =  9.0  Wind direction =  220.0
# Wind speed =  10.0  Wind direction =  220.0
# Wind speed =  11.0  Wind direction =  220.0
# Wind speed =  12.0  Wind direction =  220.0
# Wind speed =  13.0  Wind direction =  220.0
# Wind speed =  14.0  Wind direction =  220.0
# Wind speed =  15.0  Wind direction =  220.0
# Wind speed =  16.0  Wind direction =  220.0
# Wind speed =  17.0  Wind direction =  220.0
# Wind speed =  18.0  Wind direction =  220.0
# Wind speed =  19.0  Wind direction =  220.0
# Wind speed =  20.0  Wind direction =  220.0
# Wind speed =  21.0  Wind direction =  220.0
# Wind speed =  22.0  Wind direction =  220.0
# Wind speed =  23.0  Wind direction =  220.0
# Wind speed =  24.0  Wind direction =  220.0
# Wind speed =  25.0  Wind direction =  220.0
# Wind speed =  26.0  Wind direction =  220.0
# Wind speed =  27.0  Wind direction =  220.0
# Wind speed =  28.0  Wind direction =  220.0
# Wind speed =  29.0  Wind direction =  220.0
# Wind speed =  0.0  Wind direction =  230.0
# Wind speed =  1.0  Wind direction =  230.0
# Wind speed =  2.0  Wind direction =  230.0
# Wind speed =  3.0  Wind direction =  230.0
# Wind speed =  4.0  Wind direction =  230.0
# Wind speed =  5.0  Wind direction =  230.0
# Wind speed =  6.0  Wind direction =  230.0
# Wind speed =  7.0  Wind direction =  230.0
# Wind speed =  8.0  Wind direction =  230.0
# Wind speed =  9.0  Wind direction =  230.0
# Wind speed =  10.0  Wind direction =  230.0
# Wind speed =  11.0  Wind direction =  230.0
# Wind speed =  12.0  Wind direction =  230.0
# Wind speed =  13.0  Wind direction =  230.0
# Wind speed =  14.0  Wind direction =  230.0
# Wind speed =  15.0  Wind direction =  230.0
# Wind speed =  16.0  Wind direction =  230.0
# Wind speed =  17.0  Wind direction =  230.0
# Wind speed =  18.0  Wind direction =  230.0
# Wind speed =  19.0  Wind direction =  230.0
# Wind speed =  20.0  Wind direction =  230.0
# Wind speed =  21.0  Wind direction =  230.0
# Wind speed =  22.0  Wind direction =  230.0
# Wind speed =  23.0  Wind direction =  230.0
# Wind speed =  24.0  Wind direction =  230.0
# Wind speed =  25.0  Wind direction =  230.0
# Wind speed =  26.0  Wind direction =  230.0
# Wind speed =  27.0  Wind direction =  230.0
# Wind speed =  28.0  Wind direction =  230.0
# Wind speed =  29.0  Wind direction =  230.0
# Wind speed =  0.0  Wind direction =  240.0
# Wind speed =  1.0  Wind direction =  240.0
# Wind speed =  2.0  Wind direction =  240.0
# Wind speed =  3.0  Wind direction =  240.0
# Wind speed =  4.0  Wind direction =  240.0
# Wind speed =  5.0  Wind direction =  240.0
# Wind speed =  6.0  Wind direction =  240.0
# Wind speed =  7.0  Wind direction =  240.0
# Wind speed =  8.0  Wind direction =  240.0
# Wind speed =  9.0  Wind direction =  240.0
# Wind speed =  10.0  Wind direction =  240.0
# Wind speed =  11.0  Wind direction =  240.0
# Wind speed =  12.0  Wind direction =  240.0
# Wind speed =  13.0  Wind direction =  240.0
# Wind speed =  14.0  Wind direction =  240.0
# Wind speed =  15.0  Wind direction =  240.0
# Wind speed =  16.0  Wind direction =  240.0
# Wind speed =  17.0  Wind direction =  240.0
# Wind speed =  18.0  Wind direction =  240.0
# Wind speed =  19.0  Wind direction =  240.0
# Wind speed =  20.0  Wind direction =  240.0
# Wind speed =  21.0  Wind direction =  240.0
# Wind speed =  22.0  Wind direction =  240.0
# Wind speed =  23.0  Wind direction =  240.0
# Wind speed =  24.0  Wind direction =  240.0
# Wind speed =  25.0  Wind direction =  240.0
# Wind speed =  26.0  Wind direction =  240.0
# Wind speed =  27.0  Wind direction =  240.0
# Wind speed =  28.0  Wind direction =  240.0
# Wind speed =  29.0  Wind direction =  240.0
# Wind speed =  0.0  Wind direction =  250.0
# Wind speed =  1.0  Wind direction =  250.0
# Wind speed =  2.0  Wind direction =  250.0
# Wind speed =  3.0  Wind direction =  250.0
# Wind speed =  4.0  Wind direction =  250.0
# Wind speed =  5.0  Wind direction =  250.0
# Wind speed =  6.0  Wind direction =  250.0
# Wind speed =  7.0  Wind direction =  250.0
# Wind speed =  8.0  Wind direction =  250.0
# Wind speed =  9.0  Wind direction =  250.0
# Wind speed =  10.0  Wind direction =  250.0
# Wind speed =  11.0  Wind direction =  250.0
# Wind speed =  12.0  Wind direction =  250.0
# Wind speed =  13.0  Wind direction =  250.0
# Wind speed =  14.0  Wind direction =  250.0
# Wind speed =  15.0  Wind direction =  250.0
# Wind speed =  16.0  Wind direction =  250.0
# Wind speed =  17.0  Wind direction =  250.0
# Wind speed =  18.0  Wind direction =  250.0
# Wind speed =  19.0  Wind direction =  250.0
# Wind speed =  20.0  Wind direction =  250.0
# Wind speed =  21.0  Wind direction =  250.0
# Wind speed =  22.0  Wind direction =  250.0
# Wind speed =  23.0  Wind direction =  250.0
# Wind speed =  24.0  Wind direction =  250.0
# Wind speed =  25.0  Wind direction =  250.0
# Wind speed =  26.0  Wind direction =  250.0
# Wind speed =  27.0  Wind direction =  250.0
# Wind speed =  28.0  Wind direction =  250.0
# Wind speed =  29.0  Wind direction =  250.0
# Wind speed =  0.0  Wind direction =  260.0
# Wind speed =  1.0  Wind direction =  260.0
# Wind speed =  2.0  Wind direction =  260.0
# Wind speed =  3.0  Wind direction =  260.0
# Wind speed =  4.0  Wind direction =  260.0
# Wind speed =  5.0  Wind direction =  260.0
# Wind speed =  6.0  Wind direction =  260.0
# Wind speed =  7.0  Wind direction =  260.0
# Wind speed =  8.0  Wind direction =  260.0
# Wind speed =  9.0  Wind direction =  260.0
# Wind speed =  10.0  Wind direction =  260.0
# Wind speed =  11.0  Wind direction =  260.0
# Wind speed =  12.0  Wind direction =  260.0
# Wind speed =  13.0  Wind direction =  260.0
# Wind speed =  14.0  Wind direction =  260.0
# Wind speed =  15.0  Wind direction =  260.0
# Wind speed =  16.0  Wind direction =  260.0
# Wind speed =  17.0  Wind direction =  260.0
# Wind speed =  18.0  Wind direction =  260.0
# Wind speed =  19.0  Wind direction =  260.0
# Wind speed =  20.0  Wind direction =  260.0
# Wind speed =  21.0  Wind direction =  260.0
# Wind speed =  22.0  Wind direction =  260.0
# Wind speed =  23.0  Wind direction =  260.0
# Wind speed =  24.0  Wind direction =  260.0
# Wind speed =  25.0  Wind direction =  260.0
# Wind speed =  26.0  Wind direction =  260.0
# Wind speed =  27.0  Wind direction =  260.0
# Wind speed =  28.0  Wind direction =  260.0
# Wind speed =  29.0  Wind direction =  260.0
# Wind speed =  0.0  Wind direction =  270.0
# Wind speed =  1.0  Wind direction =  270.0
# Wind speed =  2.0  Wind direction =  270.0
# Wind speed =  3.0  Wind direction =  270.0
# Wind speed =  4.0  Wind direction =  270.0
# Wind speed =  5.0  Wind direction =  270.0
# Wind speed =  6.0  Wind direction =  270.0
# Wind speed =  7.0  Wind direction =  270.0
# Wind speed =  8.0  Wind direction =  270.0
# Wind speed =  9.0  Wind direction =  270.0
# Wind speed =  10.0  Wind direction =  270.0
# Wind speed =  11.0  Wind direction =  270.0
# Wind speed =  12.0  Wind direction =  270.0
# Wind speed =  13.0  Wind direction =  270.0
# Wind speed =  14.0  Wind direction =  270.0
# Wind speed =  15.0  Wind direction =  270.0
# Wind speed =  16.0  Wind direction =  270.0
# Wind speed =  17.0  Wind direction =  270.0
# Wind speed =  18.0  Wind direction =  270.0
# Wind speed =  19.0  Wind direction =  270.0
# Wind speed =  20.0  Wind direction =  270.0
# Wind speed =  21.0  Wind direction =  270.0
# Wind speed =  22.0  Wind direction =  270.0
# Wind speed =  23.0  Wind direction =  270.0
# Wind speed =  24.0  Wind direction =  270.0
# Wind speed =  25.0  Wind direction =  270.0
# Wind speed =  26.0  Wind direction =  270.0
# Wind speed =  27.0  Wind direction =  270.0
# Wind speed =  28.0  Wind direction =  270.0
# Wind speed =  29.0  Wind direction =  270.0
# Wind speed =  0.0  Wind direction =  280.0
# Wind speed =  1.0  Wind direction =  280.0
# Wind speed =  2.0  Wind direction =  280.0
# Wind speed =  3.0  Wind direction =  280.0
# Wind speed =  4.0  Wind direction =  280.0
# Wind speed =  5.0  Wind direction =  280.0
# Wind speed =  6.0  Wind direction =  280.0
# Wind speed =  7.0  Wind direction =  280.0
# Wind speed =  8.0  Wind direction =  280.0
# Wind speed =  9.0  Wind direction =  280.0
# Wind speed =  10.0  Wind direction =  280.0
# Wind speed =  11.0  Wind direction =  280.0
# Wind speed =  12.0  Wind direction =  280.0
# Wind speed =  13.0  Wind direction =  280.0
# Wind speed =  14.0  Wind direction =  280.0
# Wind speed =  15.0  Wind direction =  280.0
# Wind speed =  16.0  Wind direction =  280.0
# Wind speed =  17.0  Wind direction =  280.0
# Wind speed =  18.0  Wind direction =  280.0
# Wind speed =  19.0  Wind direction =  280.0
# Wind speed =  20.0  Wind direction =  280.0
# Wind speed =  21.0  Wind direction =  280.0
# Wind speed =  22.0  Wind direction =  280.0
# Wind speed =  23.0  Wind direction =  280.0
# Wind speed =  24.0  Wind direction =  280.0
# Wind speed =  25.0  Wind direction =  280.0
# Wind speed =  26.0  Wind direction =  280.0
# Wind speed =  27.0  Wind direction =  280.0
# Wind speed =  28.0  Wind direction =  280.0
# Wind speed =  29.0  Wind direction =  280.0
# Wind speed =  0.0  Wind direction =  290.0
# Wind speed =  1.0  Wind direction =  290.0
# Wind speed =  2.0  Wind direction =  290.0
# Wind speed =  3.0  Wind direction =  290.0
# Wind speed =  4.0  Wind direction =  290.0
# Wind speed =  5.0  Wind direction =  290.0
# Wind speed =  6.0  Wind direction =  290.0
# Wind speed =  7.0  Wind direction =  290.0
# Wind speed =  8.0  Wind direction =  290.0
# Wind speed =  9.0  Wind direction =  290.0
# Wind speed =  10.0  Wind direction =  290.0
# Wind speed =  11.0  Wind direction =  290.0
# Wind speed =  12.0  Wind direction =  290.0
# Wind speed =  13.0  Wind direction =  290.0
# Wind speed =  14.0  Wind direction =  290.0
# Wind speed =  15.0  Wind direction =  290.0
# Wind speed =  16.0  Wind direction =  290.0
# Wind speed =  17.0  Wind direction =  290.0
# Wind speed =  18.0  Wind direction =  290.0
# Wind speed =  19.0  Wind direction =  290.0
# Wind speed =  20.0  Wind direction =  290.0
# Wind speed =  21.0  Wind direction =  290.0
# Wind speed =  22.0  Wind direction =  290.0
# Wind speed =  23.0  Wind direction =  290.0
# Wind speed =  24.0  Wind direction =  290.0
# Wind speed =  25.0  Wind direction =  290.0
# Wind speed =  26.0  Wind direction =  290.0
# Wind speed =  27.0  Wind direction =  290.0
# Wind speed =  28.0  Wind direction =  290.0
# Wind speed =  29.0  Wind direction =  290.0
# Wind speed =  0.0  Wind direction =  300.0
# Wind speed =  1.0  Wind direction =  300.0
# Wind speed =  2.0  Wind direction =  300.0
# Wind speed =  3.0  Wind direction =  300.0
# Wind speed =  4.0  Wind direction =  300.0
# Wind speed =  5.0  Wind direction =  300.0
# Wind speed =  6.0  Wind direction =  300.0
# Wind speed =  7.0  Wind direction =  300.0
# Wind speed =  8.0  Wind direction =  300.0
# Wind speed =  9.0  Wind direction =  300.0
# Wind speed =  10.0  Wind direction =  300.0
# Wind speed =  11.0  Wind direction =  300.0
# Wind speed =  12.0  Wind direction =  300.0
# Wind speed =  13.0  Wind direction =  300.0
# Wind speed =  14.0  Wind direction =  300.0
# Wind speed =  15.0  Wind direction =  300.0
# Wind speed =  16.0  Wind direction =  300.0
# Wind speed =  17.0  Wind direction =  300.0
# Wind speed =  18.0  Wind direction =  300.0
# Wind speed =  19.0  Wind direction =  300.0
# Wind speed =  20.0  Wind direction =  300.0
# Wind speed =  21.0  Wind direction =  300.0
# Wind speed =  22.0  Wind direction =  300.0
# Wind speed =  23.0  Wind direction =  300.0
# Wind speed =  24.0  Wind direction =  300.0
# Wind speed =  25.0  Wind direction =  300.0
# Wind speed =  26.0  Wind direction =  300.0
# Wind speed =  27.0  Wind direction =  300.0
# Wind speed =  28.0  Wind direction =  300.0
# Wind speed =  29.0  Wind direction =  300.0
# Wind speed =  0.0  Wind direction =  310.0
# Wind speed =  1.0  Wind direction =  310.0
# Wind speed =  2.0  Wind direction =  310.0
# Wind speed =  3.0  Wind direction =  310.0
# Wind speed =  4.0  Wind direction =  310.0
# Wind speed =  5.0  Wind direction =  310.0
# Wind speed =  6.0  Wind direction =  310.0
# Wind speed =  7.0  Wind direction =  310.0
# Wind speed =  8.0  Wind direction =  310.0
# Wind speed =  9.0  Wind direction =  310.0
# Wind speed =  10.0  Wind direction =  310.0
# Wind speed =  11.0  Wind direction =  310.0
# Wind speed =  12.0  Wind direction =  310.0
# Wind speed =  13.0  Wind direction =  310.0
# Wind speed =  14.0  Wind direction =  310.0
# Wind speed =  15.0  Wind direction =  310.0
# Wind speed =  16.0  Wind direction =  310.0
# Wind speed =  17.0  Wind direction =  310.0
# Wind speed =  18.0  Wind direction =  310.0
# Wind speed =  19.0  Wind direction =  310.0
# Wind speed =  20.0  Wind direction =  310.0
# Wind speed =  21.0  Wind direction =  310.0
# Wind speed =  22.0  Wind direction =  310.0
# Wind speed =  23.0  Wind direction =  310.0
# Wind speed =  24.0  Wind direction =  310.0
# Wind speed =  25.0  Wind direction =  310.0
# Wind speed =  26.0  Wind direction =  310.0
# Wind speed =  27.0  Wind direction =  310.0
# Wind speed =  28.0  Wind direction =  310.0
# Wind speed =  29.0  Wind direction =  310.0
# Wind speed =  0.0  Wind direction =  320.0
# Wind speed =  1.0  Wind direction =  320.0
# Wind speed =  2.0  Wind direction =  320.0
# Wind speed =  3.0  Wind direction =  320.0
# Wind speed =  4.0  Wind direction =  320.0
# Wind speed =  5.0  Wind direction =  320.0
# Wind speed =  6.0  Wind direction =  320.0
# Wind speed =  7.0  Wind direction =  320.0
# Wind speed =  8.0  Wind direction =  320.0
# Wind speed =  9.0  Wind direction =  320.0
# Wind speed =  10.0  Wind direction =  320.0
# Wind speed =  11.0  Wind direction =  320.0
# Wind speed =  12.0  Wind direction =  320.0
# Wind speed =  13.0  Wind direction =  320.0
# Wind speed =  14.0  Wind direction =  320.0
# Wind speed =  15.0  Wind direction =  320.0
# Wind speed =  16.0  Wind direction =  320.0
# Wind speed =  17.0  Wind direction =  320.0
# Wind speed =  18.0  Wind direction =  320.0
# Wind speed =  19.0  Wind direction =  320.0
# Wind speed =  20.0  Wind direction =  320.0
# Wind speed =  21.0  Wind direction =  320.0
# Wind speed =  22.0  Wind direction =  320.0
# Wind speed =  23.0  Wind direction =  320.0
# Wind speed =  24.0  Wind direction =  320.0
# Wind speed =  25.0  Wind direction =  320.0
# Wind speed =  26.0  Wind direction =  320.0
# Wind speed =  27.0  Wind direction =  320.0
# Wind speed =  28.0  Wind direction =  320.0
# Wind speed =  29.0  Wind direction =  320.0
# Wind speed =  0.0  Wind direction =  330.0
# Wind speed =  1.0  Wind direction =  330.0
# Wind speed =  2.0  Wind direction =  330.0
# Wind speed =  3.0  Wind direction =  330.0
# Wind speed =  4.0  Wind direction =  330.0
# Wind speed =  5.0  Wind direction =  330.0
# Wind speed =  6.0  Wind direction =  330.0
# Wind speed =  7.0  Wind direction =  330.0
# Wind speed =  8.0  Wind direction =  330.0
# Wind speed =  9.0  Wind direction =  330.0
# Wind speed =  10.0  Wind direction =  330.0
# Wind speed =  11.0  Wind direction =  330.0
# Wind speed =  12.0  Wind direction =  330.0
# Wind speed =  13.0  Wind direction =  330.0
# Wind speed =  14.0  Wind direction =  330.0
# Wind speed =  15.0  Wind direction =  330.0
# Wind speed =  16.0  Wind direction =  330.0
# Wind speed =  17.0  Wind direction =  330.0
# Wind speed =  18.0  Wind direction =  330.0
# Wind speed =  19.0  Wind direction =  330.0
# Wind speed =  20.0  Wind direction =  330.0
# Wind speed =  21.0  Wind direction =  330.0
# Wind speed =  22.0  Wind direction =  330.0
# Wind speed =  23.0  Wind direction =  330.0
# Wind speed =  24.0  Wind direction =  330.0
# Wind speed =  25.0  Wind direction =  330.0
# Wind speed =  26.0  Wind direction =  330.0
# Wind speed =  27.0  Wind direction =  330.0
# Wind speed =  28.0  Wind direction =  330.0
# Wind speed =  29.0  Wind direction =  330.0
# Wind speed =  0.0  Wind direction =  340.0
# Wind speed =  1.0  Wind direction =  340.0
# Wind speed =  2.0  Wind direction =  340.0
# Wind speed =  3.0  Wind direction =  340.0
# Wind speed =  4.0  Wind direction =  340.0
# Wind speed =  5.0  Wind direction =  340.0
# Wind speed =  6.0  Wind direction =  340.0
# Wind speed =  7.0  Wind direction =  340.0
# Wind speed =  8.0  Wind direction =  340.0
# Wind speed =  9.0  Wind direction =  340.0
# Wind speed =  10.0  Wind direction =  340.0
# Wind speed =  11.0  Wind direction =  340.0
# Wind speed =  12.0  Wind direction =  340.0
# Wind speed =  13.0  Wind direction =  340.0
# Wind speed =  14.0  Wind direction =  340.0
# Wind speed =  15.0  Wind direction =  340.0
# Wind speed =  16.0  Wind direction =  340.0
# Wind speed =  17.0  Wind direction =  340.0
# Wind speed =  18.0  Wind direction =  340.0
# Wind speed =  19.0  Wind direction =  340.0
# Wind speed =  20.0  Wind direction =  340.0
# Wind speed =  21.0  Wind direction =  340.0
# Wind speed =  22.0  Wind direction =  340.0
# Wind speed =  23.0  Wind direction =  340.0
# Wind speed =  24.0  Wind direction =  340.0
# Wind speed =  25.0  Wind direction =  340.0
# Wind speed =  26.0  Wind direction =  340.0
# Wind speed =  27.0  Wind direction =  340.0
# Wind speed =  28.0  Wind direction =  340.0
# Wind speed =  29.0  Wind direction =  340.0
# Wind speed =  0.0  Wind direction =  350.0
# Wind speed =  1.0  Wind direction =  350.0
# Wind speed =  2.0  Wind direction =  350.0
# Wind speed =  3.0  Wind direction =  350.0
# Wind speed =  4.0  Wind direction =  350.0
# Wind speed =  5.0  Wind direction =  350.0
# Wind speed =  6.0  Wind direction =  350.0
# Wind speed =  7.0  Wind direction =  350.0
# Wind speed =  8.0  Wind direction =  350.0
# Wind speed =  9.0  Wind direction =  350.0
# Wind speed =  10.0  Wind direction =  350.0
# Wind speed =  11.0  Wind direction =  350.0
# Wind speed =  12.0  Wind direction =  350.0
# Wind speed =  13.0  Wind direction =  350.0
# Wind speed =  14.0  Wind direction =  350.0
# Wind speed =  15.0  Wind direction =  350.0
# Wind speed =  16.0  Wind direction =  350.0
# Wind speed =  17.0  Wind direction =  350.0
# Wind speed =  18.0  Wind direction =  350.0
# Wind speed =  19.0  Wind direction =  350.0
# Wind speed =  20.0  Wind direction =  350.0
# Wind speed =  21.0  Wind direction =  350.0
# Wind speed =  22.0  Wind direction =  350.0
# Wind speed =  23.0  Wind direction =  350.0
# Wind speed =  24.0  Wind direction =  350.0
# Wind speed =  25.0  Wind direction =  350.0
# Wind speed =  26.0  Wind direction =  350.0
# Wind speed =  27.0  Wind direction =  350.0
# Wind speed =  28.0  Wind direction =  350.0
# Wind speed =  29.0  Wind direction =  350.0
# AEP gain =  0.136548297939033
# Total time for AEP optimization =  681.4465281963348 s
